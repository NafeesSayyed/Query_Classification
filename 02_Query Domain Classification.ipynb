# %% [markdown]
# <a href="https://www.kaggle.com/code/nafees2006/query-domain-classifation-using-scikit-learn?scriptVersionId=254966938" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Query Domain Classification using Machine Learning

# %% [markdown]
# ## Objective
# ##### To build a machine learning model that classifies user queries into predefined categories. The goal is to explore text preprocessing, feature extraction using TfidfVectorizer, and model evaluation techniques on a moderately sized dataset to gain hands-on experience with text classification.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## Loading Datasets

# %%
df = pd.read_csv('/kaggle/input/query-domain-classification/train.csv')
test_df = pd.read_csv('/kaggle/input/query-domain-classification/test.csv')
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#         ID  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 3840  3841
# 3841  3842
# 3842  3843
# 3843  3844
# 3844  3845
#
#                                                                                                            Title  \
# 0                                                 What is good in a decision tree, a large or a small leaf size?
# 1                                                              Training data only contains single positive label
# 2                                                    Calculating percentage contribution of a negative component
# 3                                                                               Unable to open solution checker!
# 4                                                                                               User Name Change
# ...                                                                                                          ...
# 3840                                                      Where to find practice problems for linear regression?
# 3841                                                                   Running Java code on the GPU with Aparapi
# 3842  R/Python Script needed to assign Cluster ID to each PO records based on multiple conditions across columns
# 3843                                                                           Separate a column into two column
# 3844                                                                                 Clustering and Segmentation
#
#           Domain
# 0     Techniques
# 1     Techniques
# 2     Techniques
# 3     Hackathons
# 4           Misc
# ...          ...
# 3840   Resources
# 3841       Tools
# 3842       Tools
# 3843  Techniques
# 3844  Techniques
#
# [3845 rows x 3 columns]

# %%
df.shape
# Out:
# (3845, 3)

# %%
df.head(10)
# Out:
#    ID                                                           Title  \
# 0   1  What is good in a decision tree, a large or a small leaf size?
# 1   2               Training data only contains single positive label
# 2   3     Calculating percentage contribution of a negative component
# 3   4                                Unable to open solution checker!
# 4   5                                                User Name Change
# 5   6                  How to decide which curve to fit to our model?
# 6   7                                        Epochs in Neural Network
# 7   8      Chatbot to give answer(sometimes inferred) from repository
# 8   9                                   Plot on Google Maps in Python
# 9  10            Which algorithm to choose when the response is weak?
#
#        Domain
# 0  Techniques
# 1  Techniques
# 2  Techniques
# 3  Hackathons
# 4        Misc
# 5  Techniques
# 6  Techniques
# 7  Techniques
# 8       Tools
# 9  Techniques

# %% [markdown]
# ## Handling Missing Values

# %%
df.isnull().sum()
# Out:
# ID         0
# Title     11
# Domain     0
# dtype: int64

# %%
#dropna() has by default axis set to 'index' and how set to 'any'
df.dropna(axis = 'index', how = 'any', inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3834 entries, 0 to 3844
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      3834 non-null   int64
#  1   Title   3834 non-null   object
#  2   Domain  3834 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 119.8+ KB

# %%
#check wether null values are removed or not by applying filter
filt = df['Title'].isnull()

# %%
df[filt]
# Out:
# Empty DataFrame
# Columns: [ID, Title, Domain]
# Index: []

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
print(df['Domain'].unique())
df['Domain'].value_counts()
# Out:
# ['Techniques' 'Hackathons' 'Misc' 'Tools' 'Career' 'Resources' 'Other']
# Domain
# Techniques    1852
# Tools          917
# Career         437
# Hackathons     262
# Resources      170
# Other          122
# Misc            74
# Name: count, dtype: int64

# %%
plt.style.use('seaborn-v0_8-bright')
plt.rcParams['font.family'] = 'serif'
plt.figure(figsize=(5,4))
sns.countplot(data=df, x='Domain', order=df['Domain'].value_counts().index)
plt.title('Class Distribution', fontsize = 14)
plt.xlabel('Domain', fontweight='bold')
plt.ylabel('Count', fontweight='bold')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Text Cleaning Function

# %%
def clean(text):
    return ''.join([c.lower() for c in text if c.isalnum() or c.isspace()])

# %%
df['clean_title'] = (df['Title'].apply(clean))

# %%
df['clean_title']
# Out:
# 0                                                    what is good in a decision tree a large or a small leaf size
# 1                                                               training data only contains single positive label
# 2                                                     calculating percentage contribution of a negative component
# 3                                                                                 unable to open solution checker
# 4                                                                                                user name change
#                                                           ...
# 3840                                                        where to find practice problems for linear regression
# 3841                                                                    running java code on the gpu with aparapi
# 3842    rpython script needed to assign cluster id to each po records based on multiple conditions across columns
# 3843                                                                            separate a column into two column
# 3844                                                                                  clustering and segmentation
# Name: clean_title, Length: 3834, dtype: object

# %% [markdown]
# ## Label Encoding

# %%
df['label'] = df['Domain'].astype('category').cat.codes

# %%
df['label']
# Out:
# 0       5
# 1       5
# 2       5
# 3       1
# 4       2
#        ..
# 3840    4
# 3841    6
# 3842    6
# 3843    5
# 3844    5
# Name: label, Length: 3834, dtype: int8

# %%
label_mapping = dict(enumerate(df['Domain'].astype('category').cat.categories))
mapping_df = pd.DataFrame(list(label_mapping.items()), columns = ['Code', 'Domain'])

# %%
mapping_df
# Out:
#    Code      Domain
# 0     0      Career
# 1     1  Hackathons
# 2     2        Misc
# 3     3       Other
# 4     4   Resources
# 5     5  Techniques
# 6     6       Tools

# %%
X = df['clean_title']

# %%
y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0, 
                                                    stratify = y)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3067,)
# (767,)
# (3067,)
# (767,)

# %% [markdown]
# ## Text Vectorization

# %%
vectorizer = TfidfVectorizer(ngram_range = (1, 2), max_features = 10000, stop_words = 'english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %% [markdown]
# ## Model Building

# %%
model = LogisticRegressionCV(class_weight = 'balanced', cv = 5, max_iter = 1000)

# %%
model.fit(X_train_vec, y_train)
# Out:
# LogisticRegressionCV(class_weight='balanced', cv=5, max_iter=1000)

# %%
y_pred = model.predict(X_test_vec)

# %% [markdown]
# ## Model Evaluation

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred, zero_division=0))
# Out:
# Accuracy: 0.6753585397653195
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.87      0.75        87
#            1       0.61      0.54      0.57        52
#            2       0.38      0.20      0.26        15
#            3       0.33      0.17      0.22        24
#            4       0.38      0.26      0.31        34
#            5       0.76      0.75      0.75       371
#            6       0.61      0.66      0.64       184
#
#     accuracy                           0.68       767
#    macro avg       0.53      0.49      0.50       767
# weighted avg       0.67      0.68      0.67       767

# %%
X_unseen = test_df['Title']

# %%
X_unseen_vec = vectorizer.transform(X_unseen)

# %%
y_unseen_pred = model.predict(X_unseen_vec)

# %%
predicted_domains = [label_mapping[label] for label in y_unseen_pred]

# %%
test_df['Predicted_Label'] = y_unseen_pred
test_df['Predicted_Domain'] = predicted_domains

# %%
test_df.to_csv('submission.csv', index = False)

# %%
sub_df = pd.read_csv('submission.csv', index_col = 'ID')

# %% [markdown]
# ## Results on Unseen/Test Data

# %%
sub_df
# Out:
#                                                                                                      Title  \
# ID
# 3846                                                                                      Spark Cheatsheet
# 3847                                                                Review of Random forest code in Python
# 3848                                                                     Chi-Sq Test for Numeric variables
# 3849                                      Prediction from loaded pickled file for single instance of input
# 3850  Even after installing Anaconda on my PC, I am unable to access Jupyter Notebook on my command prompt
# ...                                                                                                    ...
# 5490                      Should we take all the variables from the training data in a randomForest model?
# 5491                                          Time Series Forecasting and reducing it to stationary series
# 5492                                                 Data Visualization and text analysis (twitter mining)
# 5493                                                          Cross Validation strategy for stacked models
# 5494                                           How to convert Cross Table into Straight Table in Qlikview?
#
#       Predicted_Label Predicted_Domain
# ID
# 3846                4        Resources
# 3847                6            Tools
# 3848                5       Techniques
# 3849                5       Techniques
# 3850                6            Tools
# ...               ...              ...
# 5490                5       Techniques
# 5491                5       Techniques
# 5492                3            Other
# 5493                5       Techniques
# 5494                6            Tools
#
# [1649 rows x 3 columns]
